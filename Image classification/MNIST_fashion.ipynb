# %% [markdown]
# # Image Classification
# Fashion MNIST

# %% [markdown]
# ## Importing Module

# %%
import tensorflow as tf

from matplotlib import pyplot as plt

print(f'Tensorflow Version : {tf.__version__}')
# Out:
# Tensorflow Version : 2.8.2

# %% [markdown]
# ## Problem
#
# - Build a classifier for the Fashion MNIST dataset.
# The test will expect it to classify `10` classes.
# - The input shape should be `28x28` monochrome. Do not resize the data.
# - Your input layer should accept `(28, 28)` as the input shape.
# - Don't use lambda layers in your model.
# - Desired accuracy AND validation_accuracy > `83%`

# %% [markdown]
# ### Preparing data
# Download from [tf.keras.datasets](https://www.tensorflow.org/api_docs/python/tf/keras/datasets)

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step

# %% [markdown]
# ### Explore data

# %%
print(f'Total Train Image : {len(train_images)}')
print(f'Total Test Image : {len(test_images)}')
# Out:
# Total Train Image : 60000
# Total Test Image : 10000

# %% [markdown]
# #### Visualize Image

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %% [markdown]
# ### Preparing Model

# %%
IMG_SIZE = (28,28)
BATCH_SIZE = 32

# %% [markdown]
# #### Preprocessing data

# %%
train_images = train_images / 255.
test_images = test_images / 255.

# %% [markdown]
# #### Build Model

# %%
def build_model():
  """
  Create a model sequential with convolutional layers

  Returns:
      model (tf.keras Model): the Image classifier model
  """

  # Define Params
  lr = 1e-3
  adam = tf.keras.optimizers.Adam(learning_rate=lr) # Optimizer
  losses = tf.keras.losses.SparseCategoricalCrossentropy()

  # Define Activation Function
  relu = tf.nn.relu
  softmax = tf.nn.softmax

  # Define model sequential
  model = tf.keras.Sequential()

  # Define convolutional layers
  model.add(tf.keras.layers.Conv2D(64, (3,3), activation=relu, input_shape=IMG_SIZE + (1,)))
  model.add(tf.keras.layers.MaxPooling2D(2, 2))
  model.add(tf.keras.layers.Conv2D(64, (3,3), activation=relu))
  model.add(tf.keras.layers.MaxPooling2D(2, 2))

  # Define fully connected layers
  model.add(tf.keras.layers.Flatten())
  model.add(tf.keras.layers.Dense(128, activation=relu))
  model.add(tf.keras.layers.Dense(10, activation=softmax)) # Output

  # Compile model
  model.compile(optimizer=adam, loss=losses, metrics=['accuracy'])

  # Check Summary Model
  model.summary()

  print('\nModel Successfully Create')
  
  return model

# %% [markdown]
# #### Define Callbacks

# %%
model_checkpoint = tf.keras.callbacks.ModelCheckpoint("model.h5", 
                                                      monitor="val_accuracy",
                                                      save_best_only=True,
                                                      verbose=1)

early_stopping = tf.keras.callbacks.EarlyStopping(monitor="val_accuracy", 
                                                  patience=2, 
                                                  mode ="max", 
                                                  verbose=2, 
                                                  restore_best_weights=True)

# %% [markdown]
# ### Train Model

# %%
model = build_model()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 64)        640
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dense (Dense)               (None, 128)               204928
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 243,786
# Trainable params: 243,786
# Non-trainable params: 0
# _________________________________________________________________
#
# Model Successfully Create

# %%
history = model.fit(train_images,
                    train_labels, 
                    epochs=10,
                    validation_data=(test_images, test_labels),
                    callbacks=[model_checkpoint, early_stopping],
                    steps_per_epoch=len(train_images)//BATCH_SIZE)
# Out:
# Epoch 1/10
# 1868/1875 [============================>.] - ETA: 0s - loss: 0.4424 - accuracy: 0.8412
# Epoch 1: val_accuracy improved from -inf to 0.87270, saving model to model.h5
# 1875/1875 [==============================] - 18s 4ms/step - loss: 0.4420 - accuracy: 0.8413 - val_loss: 0.3448 - val_accuracy: 0.8727
# Epoch 2/10
# 1863/1875 [============================>.] - ETA: 0s - loss: 0.2951 - accuracy: 0.8922
# Epoch 2: val_accuracy improved from 0.87270 to 0.89160, saving model to model.h5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2950 - accuracy: 0.8922 - val_loss: 0.2963 - val_accuracy: 0.8916
# Epoch 3/10
# 1869/1875 [============================>.] - ETA: 0s - loss: 0.2482 - accuracy: 0.9083
# Epoch 3: val_accuracy did not improve from 0.89160
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2485 - accuracy: 0.9082 - val_loss: 0.3073 - val_accuracy: 0.8897
# Epoch 4/10
# 1861/1875 [============================>.] - ETA: 0s - loss: 0.2155 - accuracy: 0.9198
# Epoch 4: val_accuracy improved from 0.89160 to 0.90510, saving model to model.h5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2154 - accuracy: 0.9199 - val_loss: 0.2558 - val_accuracy: 0.9051
# Epoch 5/10
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.1891 - accuracy: 0.9294
# Epoch 5: val_accuracy improved from 0.90510 to 0.90790, saving model to model.h5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1891 - accuracy: 0.9293 - val_loss: 0.2517 - val_accuracy: 0.9079
# Epoch 6/10
# 1862/1875 [============================>.] - ETA: 0s - loss: 0.1671 - accuracy: 0.9372
# Epoch 6: val_accuracy improved from 0.90790 to 0.90980, saving model to model.h5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1671 - accuracy: 0.9372 - val_loss: 0.2549 - val_accuracy: 0.9098
# Epoch 7/10
# 1864/1875 [============================>.] - ETA: 0s - loss: 0.1461 - accuracy: 0.9453
# Epoch 7: val_accuracy improved from 0.90980 to 0.91010, saving model to model.h5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1458 - accuracy: 0.9454 - val_loss: 0.2678 - val_accuracy: 0.9101
# Epoch 8/10
# 1860/1875 [============================>.] - ETA: 0s - loss: 0.1290 - accuracy: 0.9504
# Epoch 8: val_accuracy did not improve from 0.91010
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1291 - accuracy: 0.9504 - val_loss: 0.2932 - val_accuracy: 0.9066
# Epoch 9/10
# 1859/1875 [============================>.] - ETA: 0s - loss: 0.1128 - accuracy: 0.9565
# Epoch 9: val_accuracy improved from 0.91010 to 0.91030, saving model to model.h5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1129 - accuracy: 0.9565 - val_loss: 0.2789 - val_accuracy: 0.9103
# Epoch 10/10
# 1869/1875 [============================>.] - ETA: 0s - loss: 0.0972 - accuracy: 0.9634
# Epoch 10: val_accuracy improved from 0.91030 to 0.91150, saving model to model.h5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0972 - accuracy: 0.9635 - val_loss: 0.3213 - val_accuracy: 0.9115

# %% [markdown]
# ### Visualization result

# %%
def visualize_result(history):
  '''Function for Visual result'''
  
  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']

  loss = history.history['loss']
  val_loss = history.history['val_loss']

  plt.figure(figsize=(15, 6))
  plt.subplot(1, 2, 1)
  plt.plot(acc, label='Training Accuracy')
  plt.plot(val_acc, label='Validation Accuracy')
  plt.legend(loc='lower right')
  plt.title('Training and Validation Accuracy')
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')

  plt.subplot(1, 2, 2)
  plt.plot(loss, label='Training Loss')
  plt.plot(val_loss, label='Validation Loss')
  plt.legend(loc='upper left')
  plt.title('Training and Validation Loss')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.show()

# %%
visualize_result(history)

# %% [markdown]
# ### Download Model

# %%
from google.colab import files
files.download(model.h5)
